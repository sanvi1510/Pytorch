# %% [markdown]
# <a href="https://colab.research.google.com/github/sanvi1510/Pytorch/blob/main/Pytorch_lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tensor Creation

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"Is CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch version: 2.11.0+cpu
# Is CUDA available: False

# %% [markdown]
# METHODS TO CREAT TENSORS:

# %% [markdown]
# 1. **EMPTY** :JUST ASSIGN THE MEMORY AND NOT THE VALUES THERE ARE GARBAGE VALUES

# %%
A=torch.empty(1,3,2)

A
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %%
type(A)
# Out:
# torch.Tensor

# %% [markdown]
# 2.**ZEROs** : all the values are intiallized to 0 (e.g nueral n/w weights intialization)

# %%
B=torch.zeros(1,3,2)
B
# Out:
# tensor([[[0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %% [markdown]
# 3.**RAND**: randoms values b/w 0 to 1  used to intailize

# %% [markdown]
#      Issue: each time random values not reproducible
#
#      SEED:CODE TO MAKE REPRODUCIBLITY

# %%
C=torch.rand(1,3,2)
C
# Out:
# tensor([[[0.6120, 0.9015],
#          [0.7246, 0.2532],
#          [0.7758, 0.8620]]])

# %% [markdown]
# 4.**Torch.tensor: Coustom tensor**

# %%
D=torch.tensor([[1,2,3],[3,2,1]])
D
# Out:
# tensor([[1, 2, 3],
#         [3, 2, 1]])

# %% [markdown]
# 5.Arange
# 6.linspace
# 7.identity matrix
# 8.full:all values intialized to the given

# %% [markdown]
# **SHAPE OF TENSORS**

# %%
A.shape
# Out:
# torch.Size([1, 3, 2])

# %% [markdown]
# tensor of same shape as the other

# %%
E=torch.empty_like(A)
E
# Out:
# tensor([[[6.8268e-18, 4.4847e-41],
#          [2.2731e-21, 0.0000e+00],
#          [4.4842e-44, 0.0000e+00]]])

# %%
F=torch.zeros_like(A)
F
# Out:
# tensor([[[0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %%
G=torch.ones_like(A)
G
# Out:
# tensor([[[1., 1.],
#          [1., 1.],
#          [1., 1.]]])

# %%
H=torch.rand_like(A)
H
# Out:
# tensor([[[0.3699, 0.8329],
#          [0.0823, 0.5038],
#          [0.2171, 0.5681]]])

# %% [markdown]
# Data Types in tensor

# %%
A.dtype
H.dtype
# Out:
# torch.float32

# %%
I=torch.randint_like(A, low=0, high=10, dtype=torch.int32)
I
# Out:
# tensor([[[1, 6],
#          [3, 5],
#          [8, 3]]], dtype=torch.int32)

# %%
I.to(torch.float32)
# Out:
# tensor([[[1., 6.],
#          [3., 5.],
#          [8., 3.]]])

# %% [markdown]
# **OPERATIONS ON TENSORS**

# %% [markdown]
#       1.SCALER OPS

# %%
Y=A+1
Y
# Out:
# tensor([[[1., 1.],
#          [1., 1.],
#          [1., 1.]]])

# %%
X=(A*100)//10
X
# Out:
# tensor([[[0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %%
X=A**2
X
# Out:
# tensor([[[0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %% [markdown]
#      2.ELEMENT WISE OPS

# %%
X=A+B
X
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %% [markdown]
# ABSOLUTE VALUE

# %%
torch.abs(X)
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %%
torch.neg(X)
# Out:
# tensor([[[-1.5414e-43, -1.6115e-43],
#          [-1.5554e-43, -1.5975e-43],
#          [-5.6052e-44, -1.2752e-43]]])

# %%
torch.round(X)
# Out:
# tensor([[[0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %%
torch.ceil(X)
# Out:
# tensor([[[1., 1.],
#          [1., 1.],
#          [1., 1.]]])

# %% [markdown]
# CLAMP:set a boundry for the value and  then apply the cap

# %%
torch.clamp(C,min=0.5,max=0.7)
# Out:
# tensor([[[0.6120, 0.7000],
#          [0.7000, 0.5000],
#          [0.7000, 0.7000]]])

# %% [markdown]
# Reduction operations

# %% [markdown]
#   1.sum

# %%
a=torch.sum(A)
a
# Out:
# tensor(8.1415e-43)

# %%
a1=torch.sum(A,dim=1)
a1
# Out:
# tensor([[3.6574e-43, 4.4842e-43]])

# %% [markdown]
#   2.Mean:only for float datatype

# %%
a2=torch.mean(A)
a2
# Out:
# tensor(1.3593e-43)

# %% [markdown]
# max_mean

# %% [markdown]
# Variance

# %% [markdown]
# Standard deviation

# %% [markdown]
# Arg_max :position of the max element

# %% [markdown]
# Arg_min

# %% [markdown]
# **MATRIX OPS**

# %% [markdown]
# transpose

# %% [markdown]
# Multipication:matmul

# %% [markdown]
# dot product

# %% [markdown]
# determinant

# %% [markdown]
# inverse

# %% [markdown]
# **COMPARISION OPS:B/W ALL THE CORRESPONDING ELEMENTS**

# %% [markdown]
# **ARITHEMATIC**

# %% [markdown]
#   Relu

# %% [markdown]
# softmax

# %% [markdown]
# **INPLACE OPS**

# %%
A.add_(B)
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %%
A
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %% [markdown]
# **COPYING TENSOR**

# %%
b=A
b
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %% [markdown]
# ISSUE:the changes in A are reflected in b as they are stored in the same memory location

# %%
id(A)
# Out:
# 137455650037408

# %%
id(b)
# Out:
# 137455650037408

# %% [markdown]
# SOLution

# %%
c=A.clone()

# %%
c
# Out:
# tensor([[[1.5414e-43, 1.6115e-43],
#          [1.5554e-43, 1.5975e-43],
#          [5.6052e-44, 1.2752e-43]]])

# %%
id(C)
# Out:
# 137455650065376

# %%
A.flatten()
# Out:
# tensor([1.5414e-43, 1.6115e-43, 1.5554e-43, 1.5975e-43, 5.6052e-44, 1.2752e-43])
